# %%
# %cd ../
# Out:
# /home/ktnkdoomer/Documents/imgproc/simple

# %%
# from transformers import TrOCRProcessor, VisionEncoderDecoderModel

# %%
import glob, os, yaml, pprint, string
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

def imshow(im, ocv_format=True):
    binary = im.shape[0] == 1
    if ocv_format and not binary:
        im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
    plt.imshow(im, cmap='gray' if binary else None)

def imdisplay(im, ocv_format=True):
    binary = im.shape[0] == 1
    if ocv_format and not binary:
        im = cv.cvtColor(im, cv.COLOR_BGR2RGB)
    display(Image.fromarray(im))

# %%
# processor = TrOCRProcessor.from_pretrained('microsoft/trocr-large-printed')
# model = VisionEncoderDecoderModel.from_pretrained('microsoft/trocr-large-printed')
# model = model.bfloat16().cuda()

# %%
import torch
import torchvision.transforms.v2.functional as TFN

from models.ocrnet import OCRNet

# %%
with open('configs/charlevel-tiny.yaml') as f:
    cfg = yaml.load(f, yaml.Loader)['config']
pprint.pp(cfg)
n_vocab = cfg['decoder']['n_vocab']
n_enc_ctx = cfg['encoder']['n_ctx']
n_dec_ctx = cfg['decoder']['n_ctx']
# Out:
# {'backbone': {'ch_in': 1, 'n_layers': 4, 'init_filters': 8, 'ch_out': 8},
#  'encoder': {'ch_in': 8,
#              'n_ctx': 16,
#              'patch_size': [2, 2],
#              'n_blocks': 4,
#              'n_embd': 192,
#              'n_heads': 4},
#  'decoder': {'n_ctx': 34,
#              'n_vocab': 100,
#              'n_blocks': 4,
#              'n_embd': 192,
#              'n_heads': 4}}

# %%
# just copy-paste from char-level notebook
vocab = string.printable
stoi = { ch:i for i, ch in enumerate(vocab) }
itos = { i:ch for i, ch in enumerate(vocab) }
bos, bos_id = '\r', stoi['\r']
eos, eos_id = '\n', stoi['\n']
assert len(vocab) == n_vocab

def encode(s):
    return torch.tensor([stoi[ch] for ch in s])

def decode(x):
    if not isinstance(x, list):
        x = x.view(-1).tolist()
    return ''.join(itos[i] for i in x)

# %%
def impreprocess(im):
    if not isinstance(im, Image.Image) and im.ndim == 2:
        im = im[..., None]
    
    im = TFN.to_dtype(TFN.to_image(im)) / 255
    im = 1 - im
    ar = im.size(-1) / im.size(-2)
    im = TFN.resize(im, (32, int(ar * 32)))
    dx = 512 - im.size(-1)
    im = TFN.pad(im, (0, 0, dx, 0), fill=0)
    return im

@torch.inference_mode()
def predict(x_im):
    device = next(net.parameters()).device
    net.eval()
    if x_im.ndim != 4:
        x_im = x_im.view(-1, 1, x_im.size(-2), x_im.size(-1))
    x_enc = net.encoder(net.backbone(x_im.to(device)))
    x_ctx = torch.tensor([bos_id], device=device)
    while True:
        logits = net.decoder(x_ctx[None], x_enc)
        tok_idx = logits[:, -1, :].argmax(-1)
        if tok_idx == eos_id or len(x_ctx) >= n_dec_ctx:
            break
        x_ctx = torch.cat((x_ctx, tok_idx))

    return decode(x_ctx)[1:]

# %%
net = torch.compile(OCRNet(cfg).cuda())
net.load_state_dict(torch.load('ckpts/new_best_model.pt'))
# Out:
# <All keys matched successfully>

# %%
print(sum(p.numel() for p in net.parameters()))
# Out:
# 4476194

# %%
im_files = sorted(glob.glob('../data/PageSegData/PageImg/*.JPG'))
mask_files = []
for i in im_files:
    im_name = i.strip().rsplit('/')[-1]
    mask_name = im_name.replace('.JPG', '_mask.png')
    mask_files.append(f'../data/PageSegData/PageSeg/{mask_name}')

for i in mask_files:
    assert os.path.isfile(i)

print(len(mask_files))
print(im_files[0], mask_files[0])
# Out:
# 300
# ../data/PageSegData/PageImg/1.JPG ../data/PageSegData/PageSeg/1_mask.png

# %%
def seg_pipeline(im):
    if im.ndim != 2:
        im = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
    im_h, im_w = im.shape
    fx, fy = 1, 1
    if abs(im_w - 1024) < 200:
        fx, fy = 1024/im_w, 1024/im_w
        im = cv.resize(im, (0,0), fx=fx, fy=fy)
        im_h, im_w = im.shape
    _, thresh = cv.threshold(im, 0, 255, cv.THRESH_BINARY_INV+cv.THRESH_OTSU)
    dil = cv.dilate(thresh, np.ones((1, 20)), iterations=2)
    er = cv.erode(dil, np.ones((7, 1)), iterations=1)
    mask = cv.dilate(er, np.ones((1, 7)), iterations=2)
    contours, _ = cv.findContours(mask, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)

    y_expand_up, y_expand_down = 4, 4
    line_bbs = []
    for c in contours:
        x, y, w, h = cv.boundingRect(c)
        if h > 10*w:
            continue
        y, h = y-y_expand_up, h+y_expand_up+y_expand_down

        line_bbs.append((x,y,w,h))
    line_bbs.sort(key=lambda bb: bb[1]*im_w+bb[0])

    word_bbs = []
    for line_bb in line_bbs:
        lx,ly,lw,lh = line_bb
        crop = thresh[ly:ly+lh, lx:lx+lw]
        dil = cv.dilate(crop, np.ones((20, 3)), iterations=2)
        contours, _ = cv.findContours(dil, cv.RETR_LIST, cv.CHAIN_APPROX_SIMPLE)
        line_word_bbs = []
        for c in contours:
            x, y, w, h = cv.boundingRect(c)
            x, y, w, h = (x+lx)/fx, (y+ly)/fy, w/fx, h/fy
            x, y, w, h = map(int, (x,y,w,h))
            line_word_bbs.append((x,y,w,h))
        line_word_bbs.sort(key=lambda bb: bb[0])

        combined_word_bbs = [line_word_bbs[0]]
        combine_thresh = 0.1
        for r2 in line_word_bbs[1:]:
            r1 = combined_word_bbs[-1]
            d = r2[0] - (r1[0]+r1[2])
            if d*fx / lh < combine_thresh:
                combined = r1[0], r1[1], r1[2]+d+r2[2], r1[3]
                combined_word_bbs[-1] = combined
            else:
                combined_word_bbs.append(r2)
        
        lx, ly, lw, lh = lx/fx, ly/fy, lw/fx, lh/fy
        lx, ly, lw, lh = map(int, (lx,ly,lw,lh))
        word_bbs.append(((lx, ly, lw, lh), combined_word_bbs))
    return word_bbs

# %%
def draw_segments(im, word_bbs):
    canv = np.repeat(im[...,None], 3, axis=-1)
    for (lx,ly,lw,lh), word_line_bbs in word_bbs:
        # cv.rectangle(canv, (lx,ly), (lx+lw, ly+lh), (0,0,255), 1)
        for (x,y,w,h) in word_line_bbs:
            cv.rectangle(canv, (x,y), (x+w,y+h), (0,255,0), 1)
    return canv

# %%
# def run_inference(ims):
#     if not isinstance(ims, list):
#         ims = [ims]
#     eos_tok_id = processor.tokenizer.eos_token_id
#     ims = [cv.cvtColor(im, cv.COLOR_GRAY2RGB) for im in ims]    
#     px = processor(images=ims, return_tensors='pt').pixel_values
#     tok_ids = model.generate(
#         px.bfloat16().cuda(), 
#         pad_token_id=eos_tok_id,
#     )
#     return processor.batch_decode(tok_ids, skip_special_tokens=True)

def run_inference(ims):
    if not isinstance(ims, list):
        ims = [ims]
    return [predict(impreprocess(im)).strip() for im in ims]

# %%
def merge_neighbours(bbs, stride=2):
    if len(bbs) < 2:
        return bbs
    merged = []
    for i in range(0, len(bbs), stride):
        r1 = bbs[i]
        r2 = bbs[min(len(bbs)-1, i+stride-1)]
        merged.append((r1[0],r1[1], r2[0]-r1[0]+r2[2], r1[3]))
    return merged

# %%
def imcrop(im, bboxes, stride=1):
    if not isinstance(bboxes, list):
        bboxes = [bboxes]
    if stride > 1:
        bboxes = merge_neighbours(bboxes, stride)
    return [im[y:y+h, x:x+w] for (x,y,w,h) in bboxes]

# %%
im = cv.imread(im_files[0], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1058x534>
# t l Introduction
# This reference manual describes the Python programming language. It is not intended as a tutorial.
# While l am trying to be as precise as possible, l chose to use English rather than formal specifications for
# everything except syntax and lexical analysis. This should make the document more understandable to the
# average reader, but will leave room for ambiguities. Consequently if you were coming from Mars and tried to re-
# implement Python from this document alone, you might have to guess things and in fact you would probably end
# up implementing quite a different language. On the other hand, if you are using Python and wonder what the
# precise rules about a particular area of the language are, you should definitely be able to find them here. |f you
# would like to see a more formal definition of the language, maybe you could volunteer your time -- 0r invent a
# cloning machine :-).
# It is dangerous to add too many implementation details to a language reference document -- the implementation
# may change, and other implementations of the same language may work differently. On the other hand, CPython
# is the one Python implementation in widespread use (although alternate implementations continue to gain
# supporty and its particular quirks are sometimes worth being mentioned, especially where the implementation
# imposes additional limitations. Therefore, you*|l find short fimplementation notes" sprinkled throughout the text.

# %%
im = cv.imread(im_files[1], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1430x677>
# Python can be integrated with other languages such as C, C++, and Java. This means that a programmer can
# take advantage of work already done j in another language while using Python. |t also means that he 0r she
# can leverage the strengths of other languages such as the extra speed that C 0r C++ can offer, while still
# enjoying the ease of development that's a hallmark of Python programming.
# Python Runs Everywhere
# Python runs on everything from a Palm to a Cray. And jif you don't happen to have a supercomputer jin the
# den, you can still run Python on Windows, DOS, Macintosh@, or Linux machines. And that's just the top of the
# list. Python can run on practically every operating system jin existence.
# Python programs are platform independent's which means that regardless of the operating system you use to
# create your program, it'll run on any other computer with Python. So if you write a game on your PC, you can
# e-mail a copy to your friend who runs Linux or to your aunt who has a Mac, and the program will work (as long
# as your friend and Aunt have Python on their computersy.
# Python Has a Strong Community
# A lot of people use Python, and the community is growing all the time. |n fact, the traffic at the
# comp l 1ang f python newsgroup, where all kinds of people come together to discuss Python, doubles almost
# every two years.

# %%
im = cv.imread(im_files[2], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1361x492>
# How to be a good student
# |f you want to participate as q student and want to maximize your chances of being acceptedly start
# talking to 1s today and try fixing some smaller problens to get used to our workflow. If we know you
# can wotk weII with \LS, you will have much better chances of being selected.
# Here's a checklist:
# p Make sure to read through the website and at least skim the documentation.
# p Look at the soutce code.
# p Read Our contribution guidelines.
# p Make a contribution! Kivy would like to see'how you engagewith the development process Take
# q look at the issue tracker for q Kivy project that interests you and submit q Pu1l Request. It can
# be q simple bug Of q documentation change. We are looking to get q feel for how you work, not
# evaluating your capabilities Don't worry about trying to pick something to impress \L$-

# %%
im = cv.imread(im_files[3], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1088x582>
# p Look at the source code.
# p Read our contribution guidelines.
# p Pick an idea that you think is interesting from the ideas list (see link above) Of come up with your
# 0wn idea.
# f Do some research y0utse]f. GSoC is not about us teaching you something and you getting paid
# for that. It is about you trying to achieve agreed upon goals by yourself with Our support. The
# main driving force in this should be, obviously yourself. Many students come up and ask what
# they should do. Well, we don't Know because we know neither your interests nor your skills.
# Show us you're serious about titand take initiative.
# p Writea draft proposal about what you want to do. Include what you understand the current state
# is (very roughly), what you would like to improve and Inow, etc.
# p Discuss that proposal with us in a timely manner. Get feedback.
# f Be patient! Especially On Discord. We will try to get to you if we're available. [f not, send an
# email and just wait. Most questions are already answered in the docs Of somewhere else and can
# be found with some research. IE your questions don't reflect that you've actually thought through
# what you're asking, lit might not be weII received.

# %%
im = cv.imread(im_files[4], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1318x562>
# 5.1 lnstallation of the Kivy environment
# Kivy depends 0n many Python libraries such as pygamey gstreamery PIL, Cairo, and more. They are
# not a1l required, but depending on the platform you're working 0n, they can be a pain to install For
# Windows and MacOS X, we provide q portable package that you can just unzip and use.
# Have q ]ook at one of these pages for detailed installation instructions:
# p installation windows
# p installation OSX
# q installation linux
# p installation_rpi
# Alternatively instructions for the development version can be found heret
# p installation

# %%
im = cv.imread(im_files[5], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1277x607>
# 6.I Path control
# New in version 1.0.7.
# You can control the default directories where config files, modules and kivy data are located.
# Kivy_DATA_DIK Location of the Kivy data, defaults to kkixy patti-xylata
# Kivy_MODUI ES_D1R Location of the Kivy modules defaults to zkixy pattrymodilles
# KIVY_HOME Location of the Kivy home. This directory is used for local configuration, and must be
# in a writable location.
# Defaults t0:
# p Desktop: Z1&ef 1omtex/.kiq;/
# p Android: kinthroid 1PP patI1x/.kio]/
# p iOS: Z1SeT }1011e?/D0c1i1 i1e1ts/.kio1/
# New in version 1.9.0.

# %%
im = cv.imread(im_files[6], cv.IMREAD_GRAYSCALE)
word_bbs = seg_pipeline(im)
imdisplay(draw_segments(im, word_bbs))

for line_bb, line_word_bbs in word_bbs:
    print(' '.join(run_inference(imcrop(im, line_word_bbs, 1))))
# Out:
# <PIL.Image.Image image mode=RGB size=1101x523>
# Build an 8-bit computer from scratch
# Overview
# l built a programmable 8-bit computer from scratch on breadboards using
# only simple logic gates. l documented the whole project in a series of
# YouTube videos and on this web site. Watch this video for an introduction:
# fea
# 8-bit computer update

# %% [markdown]
# # Beam search

# %%
im = Image.open('crops2/5_83.jpg')
x_im = impreprocess(im)
print(predict(x_im)) # greedy sampling
im
# Out:
# jif
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=15x25>

# %%
x_im.shape
# Out:
# torch.Size([1, 32, 512])

# %%
import torch.nn.functional as F

@torch.inference_mode()
def get_probs(x_ctx, x_enc):
    device = next(net.parameters()).device
    if isinstance(x_ctx, list):
        x_ctx = torch.tensor(x_ctx, device=device)
    x_ctx = x_ctx.view(1, -1).to(device)
    x_enc = x_enc.to(device)
    logits = net.decoder(x_ctx, x_enc)
    return F.softmax(logits.sum(dim=1), dim=-1)

# %%
with torch.inference_mode():
    x_enc = net.encoder(net.backbone(x_im[None].cuda()))

# %%
x_ctx = encode(bos).view(1, -1)

# %%
probs = get_probs(x_ctx, x_enc)
probs
# Out:
# tensor([[3.2756e-03, 5.8163e-03, 2.6397e-03, 4.4455e-03, 2.3852e-03, 9.7718e-03,
#          4.8055e-03, 2.9527e-03, 8.4049e-03, 4.0054e-03, 1.1385e-02, 7.6072e-03,
#          8.2134e-03, 9.8899e-03, 9.2442e-03, 1.2573e-02, 3.0507e-02, 1.0943e-02,
#          1.2533e-01, 1.3012e-01, 1.1718e-02, 2.0352e-02, 5.0898e-03, 5.7644e-03,
#          7.9547e-03, 3.2401e-02, 5.9902e-02, 1.3941e-02, 1.6133e-02, 1.8217e-02,
#          9.1395e-03, 7.1784e-03, 7.3631e-03, 5.5002e-03, 1.2652e-02, 5.7627e-03,
#          5.6525e-03, 9.7366e-03, 5.4686e-03, 7.3134e-03, 7.3593e-03, 7.7864e-03,
#          5.5041e-03, 5.2148e-03, 1.6643e-02, 7.2223e-03, 6.9733e-03, 1.3534e-02,
#          3.2588e-03, 4.2193e-03, 6.8408e-03, 9.7173e-03, 8.6725e-03, 7.2829e-03,
#          1.5660e-02, 6.8840e-03, 2.9693e-03, 4.7725e-03, 3.4366e-03, 5.3602e-03,
#          3.9801e-03, 4.8328e-03, 4.5868e-03, 5.2856e-03, 2.5417e-03, 8.3813e-03,
#          4.8716e-03, 4.3384e-03, 6.3714e-03, 9.0012e-03, 5.6274e-03, 5.1233e-03,
#          3.4287e-03, 7.6561e-03, 6.8610e-03, 8.9887e-03, 2.3366e-03, 6.9151e-03,
#          9.5663e-03, 1.5502e-08, 1.2089e-08, 1.7842e-08, 2.7501e-03, 1.6610e-03,
#          1.0700e-02, 2.7076e-03, 1.0579e-02, 3.4278e-03, 7.8558e-03, 4.6604e-03,
#          5.0619e-03, 1.2410e-02, 4.3932e-03, 1.9624e-03, 1.9844e-04, 1.8073e-08,
#          4.2441e-05, 3.5703e-05, 1.7719e-08, 1.5046e-08]], device='cuda:0')

# %%
torch.topk(probs, 3)
# Out:
# torch.return_types.topk(
# values=tensor([[0.1301, 0.1253, 0.0599]], device='cuda:0'),
# indices=tensor([[19, 18, 26]], device='cuda:0'))

# %%
from collections import namedtuple

# %%
Hypo = namedtuple('Hypo', ['x_ctx', 'prob'])

# %%
def beam_step(x_enc, hypos, B=3):
    new_hypos = []
    for hypo in hypos:
        ps, ics = torch.topk(get_probs(hypo.x_ctx, x_enc), B)
        for p, tok_idx in zip(ps.flatten(), ics.flatten()):
            new_hypos.append(Hypo(x_ctx=hypo.x_ctx + [tok_idx.item()], 
                                  prob=p.item()))
    return sorted(new_hypos, key=lambda h: h.prob, reverse=True)[:B]

# %%
hypos = [Hypo([bos_id], 1.0)]
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# j
# [Hypo(x_ctx=[97, 19], prob=0.13011561334133148),
#  Hypo(x_ctx=[97, 18], prob=0.12532781064510345),
#  Hypo(x_ctx=[97, 26], prob=0.05990231782197952)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# qi
# [Hypo(x_ctx=[97, 26, 18], prob=0.8339230418205261),
#  Hypo(x_ctx=[97, 19, 18], prob=0.7698532342910767),
#  Hypo(x_ctx=[97, 18, 15], prob=0.6999683380126953)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# iff
# [Hypo(x_ctx=[97, 18, 15, 15], prob=0.9980854988098145),
#  Hypo(x_ctx=[97, 19, 18, 15], prob=0.9533136487007141),
#  Hypo(x_ctx=[97, 26, 18, 18], prob=0.5588750839233398)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# qiif
# [Hypo(x_ctx=[97, 26, 18, 18, 15], prob=0.999093770980835),
#  Hypo(x_ctx=[97, 19, 18, 15, 15], prob=0.9828739762306213),
#  Hypo(x_ctx=[97, 18, 15, 15, 96], prob=0.8169894814491272)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# iff
# [Hypo(x_ctx=[97, 18, 15, 15, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 26, 18, 18, 15, 15], prob=0.9994449019432068),
#  Hypo(x_ctx=[97, 19, 18, 15, 15, 96], prob=0.8120640516281128)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# iff
# [Hypo(x_ctx=[97, 18, 15, 15, 96, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 19, 18, 15, 15, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 26, 18, 18, 15, 15, 15], prob=0.9511137008666992)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# iff
# [Hypo(x_ctx=[97, 18, 15, 15, 96, 96, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 19, 18, 15, 15, 96, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 26, 18, 18, 15, 15, 15, 96], prob=0.9999315738677979)]

# %%
hypos = beam_step(x_enc, hypos)
print(decode(hypos[0].x_ctx).strip())
hypos
# Out:
# iff
# [Hypo(x_ctx=[97, 18, 15, 15, 96, 96, 96, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 19, 18, 15, 15, 96, 96, 96, 96], prob=1.0),
#  Hypo(x_ctx=[97, 26, 18, 18, 15, 15, 15, 96, 96], prob=1.0)]

# %%
@torch.inference_mode()
def beam_search(im, B=3):
    x_im = impreprocess(im)
    device = next(net.parameters()).device
    x_enc = net.encoder(net.backbone(x_im[None].to(device)))
    
    hypos = beam_step(x_enc, [Hypo(x_ctx=[bos_id], prob=1.0)], B)
    while True:
        hypos = beam_step(x_enc, hypos, B)
        best_ctx = hypos[0].x_ctx
        if len(best_ctx) >= n_dec_ctx or best_ctx[-1] == eos_id:
            return decode(best_ctx[1:-1])

# %%
beam_search(im)
# Out:
# 'iff\n'

# %% [markdown]
# # okay, the decoder is way too retarded for beam search...
